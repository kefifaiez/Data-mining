# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_digits
from sklearn.metrics import confusion_matrix

# %%
digits=load_digits()
X=digits.data
y=digits.target
X[0,:]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
# Créer la figure et les sous-graphiques
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(8, 8))

# Parcourir les images et les étiquettes correspondantes
for ax, image, label in zip(axes, digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title("Image : %i" % label)

# Afficher la figure
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# Charger le jeu de données des chiffres
digits = load_digits()

# Créer la figure et les sous-graphiques avec 2 lignes et 4 colonnes
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(8, 8))

# Parcourir les images et les étiquettes correspondantes
for ax, image, label in zip(axes.flatten(), digits.images, digits.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title("Image : %i" % label)

# Ajuster l'espacement entre les sous-graphiques
plt.tight_layout()

# Afficher la figure
plt.show()

# %%
axes.shape
# Out:
# (3, 10)

# %%
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
digits.target.shape
# Out:
# (1797,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
knn.score(X_test,y_test )
# Out:
# 0.9888888888888889

# %% [markdown]
# création de fonction pour afficher meilleur score

# %%
def determiner_meilleur_score(s):
    meilleur_score = np.max(s)
    meilleur_k = s.index(meilleur_score)+1
    return (print("le meilleur score est:",meilleur_score)), (print("le meilleur k est:",meilleur_k))

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

k = range(1, 30)
scores = []

# Calcul des scores pour différentes valeurs de k
for i in k:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    sc = knn.score(X_test, y_test)
    scores.append(sc)
determiner_meilleur_score(scores)
# Out:
# le meilleur score est: 0.9888888888888889
# le meilleur k est: 7
# (None, None)

# %%
#2 eme methode
'''
k = range(1,30)
meilleur_score = 0
meilleur_d = 0
scores = []
for i in k:
  knn=KNeighborsClassifier(n_neighbors=i)
  knn.fit(X_train, y_train)
  sc=knn.score(X_test,y_test )
  # Ajout du score à la liste
  scores.append(sc)
  if sc > meilleur_score:
        meilleur_score = sc
        meilleur_d = i
print("Le k optimal est", meilleur_d)
print("Le score est", meilleur_score)
np.array(scores).max()
'''
# Out:
# '\nk = range(1,30)\nmeilleur_score = 0\nmeilleur_d = 0\nscores = []\nfor i in k:\n  knn=KNeighborsClassifier(n_neighbors=i)\n  knn.fit(X_train, y_train)\n  sc=knn.score(X_test,y_test )\n  # Ajout du score à la liste\n  scores.append(sc)\n  if sc > meilleur_score:\n        meilleur_score = sc\n        meilleur_d = i\nprint("Le k optimal est", meilleur_d)\nprint("Le score est", meilleur_score)\nnp.array(scores).max()\n'

# %%
#afficher le score/k

plt.plot(k, scores, 'o-')
plt.xlabel('Degré')
plt.ylabel('Score')
plt.title('Scores fonction du degré')
plt.grid(True)
plt.show()
